# %%
import pandas as pd

# %%
data = pd.read_csv("trainingData.csv") 
data.head(5)
# Out:
#    Sample Filename     Language
# 0  000kouqjfnk.mp3    Hmong Daw
# 1  000w3fewuqj.mp3    Tektiteko
# 2  000ylhu4sxl.mp3       Teribe
# 3  0014x3zvjrl.mp3      Chipaya
# 4  001xjmtk2wx.mp3  KalmykOirat

# %%
data['Col'] = (pd.factorize(data.Language)[0]-1) + 1
data.head(5)
# Out:
#    Sample Filename     Language  Col
# 0  000kouqjfnk.mp3    Hmong Daw    0
# 1  000w3fewuqj.mp3    Tektiteko    1
# 2  000ylhu4sxl.mp3       Teribe    2
# 3  0014x3zvjrl.mp3      Chipaya    3
# 4  001xjmtk2wx.mp3  KalmykOirat    4

# %%
# Se quita .mp3 del nombre
data['Sample Filename'] = data['Sample Filename'].str[:-3]

# Se elimina la columna con el nombre de los lenguajes
data = data.drop(['Language'], axis=1)
data.head(3)
# Out:
#   Sample Filename  Col
# 0    000kouqjfnk.    0
# 1    000w3fewuqj.    1
# 2    000ylhu4sxl.    2

# %%
del data.columns.name
data.head(5)
# Out:
#   Sample Filename  Col
# 0    000kouqjfnk.    0
# 1    000w3fewuqj.    1
# 2    000ylhu4sxl.    2
# 3    0014x3zvjrl.    3
# 4    001xjmtk2wx.    4

# %%
66176/2
# Out:
# 33088.0

# %%
data3 = data.drop(data.index[0:33088])
data3
# Out:
#       Sample Filename  Col
# 33088    k03w3p55mrx.  168
# 33089    k04xhd4c5oj.  124
# 33090    k053gojvunj.    5
# 33091    k05k4s0jdhp.  155
# 33092    k0aisj1jfdw.  115
# 33093    k0bxlfcyz4e.   89
# 33094    k0cjksedaev.   24
# 33095    k0deoglw5yu.  138
# 33096    k0dnj4xgfhs.   10
# 33097    k0dqn5fo3u4.  143
# 33098    k0dqqh24miu.   72
# 33099    k0dx2tb5cyh.  102
# 33100    k0ej3ofmx5s.   74
# 33101    k0fgffqba1g.  131
# 33102    k0fwtkmagrd.   50
# 33103    k0gc22jdjqt.   77
# 33104    k0gwzw3tygx.   97
# 33105    k0hd1gvjpzx.   46
# 33106    k0hlhly0f1a.   93
# 33107    k0i1ooanj4s.  114
# 33108    k0jd22rsiso.   86
# 33109    k0jddnjwade.  111
# 33110    k0jlzoqtmoh.   28
# 33111    k0jyimjwgkl.  124
# 33112    k0kbvdfgqag.   71
# 33113    k0kcjp44gop.   37
# 33114    k0khvhgarxt.   12
# 33115    k0kr33avejc.    9
# 33116    k0ljmlnqk00.   48
# 33117    k0lmblmnggx.   12
# ...               ...  ...
# 66146    zzkelwbe2po.   23
# 66147    zzkqzztaz1p.  139
# ...

# %%
data3.to_csv('valEqual.csv', sep=',', index = False)
